# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Import data

# %%
df_res_ins = pd.read_csv('../restaurant_inspection_result_cleaned.csv', index_col=0)
df_yelp = pd.read_csv('../yelp_nyc', index_col=0)

# %% [markdown]
# ### Clean data

# %% [markdown]
# #### Inspection data

# %%
# Drop null values in building columns
df_res_ins.dropna(subset=['building'], inplace=True)

# Combine building and street columns to get the address
df_res_ins['address'] = df_res_ins.apply(lambda row: str(row.building) + str(" ") + str(row.street), axis=1)

# Change dba to name to match yelp data
df_res_ins.rename(columns={'dba': 'name'}, inplace=True)

# Make address all lower-case.
df_res_ins["address"] = [i.lower() for i in df_res_ins["address"]]

# Make phone all string
df_res_ins["phone"] = [str(i) for i in df_res_ins["phone"]]

# %% [markdown]
# #### yelp data

# %%
# Drop null values in address column
df_yelp.dropna(subset=['address'], inplace=True)

# Fill 0 in null value in phone column
df_yelp['phone'].fillna(0000000000, inplace=True)

# Make the name of the restaurant all lower-case.
df_yelp['name'] = [i.lower() for i in df_yelp["name"]]

# Make address all lower-case.
df_yelp['address'] = [str(i).lower() for i in df_yelp["address"]]

# Make phone all string
df_yelp['phone'] = [str(int(i))[1:11] for i in df_yelp["phone"]]

# %% [markdown]
# ### Unify `address`  and `name` values in both dataset

# %%
# Apply the following translation to both of inspection data and yelp data.
# For address,

address_replace_dict = {' avenue': ' ave',
                        ' street': ' st',
                        ' west ': ' w ',
                        " east ": " e ",
                        "th ave": " ave",
                        "th st": " st",
                        "road": 'rd',
                        "lane": "ln",
                        "floor": 'fl',
                        'place': 'pl',
                        "1st": "1",
                        "2nd": "2",
                        "3rd": '3',
                        "-": "",
                        ".": ""}

for key in address_replace_dict:
    df_res_ins['address'] = [i.replace(key, address_replace_dict[key]) for i in df_res_ins['address']]
    df_yelp['address'] = [i.replace(key, address_replace_dict[key]) for i in df_yelp['address']]

# %% [markdown]
# ### Combine inspection data and yelp data by address, name and phone number

# %%
df_combined = df_res_ins.merge(df_yelp, how='inner', left_on=['address','name', 'phone', 'zipcode'], right_on=['address','name','phone', 'zip_code'])
df_combined
# Out:
#          camis                                  name       boro building  \
# 0     30075445                 morris park bake shop      bronx     1007
# 1     30075445                 morris park bake shop      bronx     1007
# 2     30075445                 morris park bake shop      bronx     1007
# 3     40361618                            sal's deli     queens    12908
# 4     40361618                            sal's deli     queens    12908
# 5     40361618                            sal's deli     queens    12908
# 6     40361618                            sal's deli     queens    12908
# 7     40361618                            sal's deli     queens    12908
# 8     40362715                      the country cafe  manhattan       60
# 9     40362715                      the country cafe  manhattan       60
# 10    40362715                      the country cafe  manhattan       60
# 11    40362715                      the country cafe  manhattan       60
# 12    40362715                      the country cafe  manhattan       60
# 13    40362715                      the country cafe  manhattan       60
# 14    40362715                      the country cafe  manhattan       60
# 15    40362715                      the country cafe  manhattan       60
# 16    40362715                      the country cafe  manhattan       60
# 17    40362715                      the country cafe  manhattan       60
# 18    40364220                     kosher bagel hole   brooklyn     1423
# 19    40364220                     kosher bagel hole   brooklyn     1423
# 20    40364220                     kosher bagel hole   brooklyn     1423
# 21    40364296                          happy garden      bronx      277
# 22    40364296                          happy garden      bronx      277
# 23    40364296                          happy garden      bronx      277
# 24    40364572                 donohue's steak house  manhattan      845
# 25    40364572                 donohue's steak house  manhattan      845
# 26    40364572                 donohue's steak house  manhattan      845
# 27    40364572                 donohue's steak house  manhattan      845
# 28    40364572                 donohue's steak house  manhattan      845
# 29    40364920                    rizzo's fine pizza     queens     3013
# ...        ...                                   ...        ...      ...
# 7404  50087580                            suma sushi  manhattan      964
# 7405  50087580                            suma sushi  manhattan      964
# 7406  50087693                     la nueva colombia     queens     9107
# 7407  50087693                     la nueva colombia     queens     9107
# 7408  50087726                          inca chicken   brooklyn      122
# 7409  50087726                          inca chicken   brooklyn      122
# 7410  50087737              el viejo yayo restaurant     queens     9712
# 7411  50087750                   crown fried chicken     queens    13105
# 7412  50087750                   crown fried chicken     queens    13105
# 7413  50087864                             arco cafe  manhattan      886
# 7414  50087864                             arco cafe  manhattan      886
# 7415  50087867                         delicious wok     queens     5952
# 7416  50087867                         delicious wok     queens     5952
# 7417  50087867                         delicious wok     queens     5952
# 7418  50088138                        g&j's pizzeria  manhattan      188
# 7419  50088138                        g&j's pizzeria  manhattan      188
# 7420  50088385                      sup thai kitchen     queens    17819
# 7421  50088385                      sup thai kitchen     queens    17819
# 7422  50088556                   singas famous pizza     queens     4369
# 7423  50088692                           milk burger      bronx      148
# 7424  50088771                       drunken chicken     queens     2530
# 7425  50088771                       drunken chicken     queens     2530
# 7426  50089111                  framboise patisserie     queens     6459
# 7427  50089305  c & j jamaican restaurant and bakery     queens    24712
# 7428  50089305  c & j jamaican restaurant and bakery     queens    24712
# 7429  50089435                            sushi star  manhattan      462
# 7430  50089682                        kingston pizza   brooklyn      259
# 7431  50089682                        kingston pizza   brooklyn      259
# 7432  50089893                           blvd bistro  manhattan     2149
# 7433  50090620                   golden krust bakery     queens     9058
#
#                        street  zipcode       phone  \
# 0             morris park ave    10462  7188924968
# 1             morris park ave    10462  7188924968
# 2             morris park ave    10462  7188924968
# 3                   20 avenue    11356  7186619498
# 4                   20 avenue    11356  7186619498
# 5                   20 avenue    11356  7186619498
# 6                   20 avenue    11356  7186619498
# 7                   20 avenue    11356  7186619498
# 8                 wall street    10005  3474279132
# 9                 wall street    10005  3474279132
# 10                wall street    10005  3474279132
# 11                wall street    10005  3474279132
# 12                wall street    10005  3474279132
# 13                wall street    10005  3474279132
# 14                wall street    10005  3474279132
# 15                wall street    10005  3474279132
# 16                wall street    10005  3474279132
# 17                wall street    10005  3474279132
# 18                   avenue j    11230  7182584150
# 19                   avenue j    11230  7182584150
# 20                   avenue j    11230  7182584150
# 21      east kingsbridge road    10458  7182955588
# 22      east kingsbridge road    10458  7182955588
# 23      east kingsbridge road    10458  7182955588
# 24           lexington avenue    10065  2127440938
# 25           lexington avenue    10065  2127440938
# 26           lexington avenue    10065  2127440938
# 27           lexington avenue    10065  2127440938
# 28           lexington avenue    10065  2127440938
# 29            steinway street    11103  7187219862
# ...                       ...      ...         ...
# 7404            amsterdam ave    10025  2122805858
# 7405            amsterdam ave    10025  2122805858
# 7406                 31st ave    11369  7183963399
# 7407                 31st ave    11369  7183963399
# 7408              wyckoff ave    11237  7183663763
# 7409              wyckoff ave    11237  7183663763
# 7410                101st ave    11416  7183223920
# 7411            rockaway blvd    11420  7183232161
# 7412            rockaway blvd    11420  7183232161
# 7413            amsterdam ave    10025  6467819080
# 7414            amsterdam ave    10025  6467819080
# 7415           summerfield st    11385  7183668882
# 7416           summerfield st    11385  7183668882
# 7417           summerfield st    11385  7183668882
# 7418               e 104th st    10029  2123694800
# 7419               e 104th st    10029  2123694800
# 7420               union tpke    11366  7184874449
# 7421               union tpke    11366  7184874449
# 7422             kissena blvd    11355  7184634343
# 7423            bruckner blvd    10454  2123601988
# 7424                 broadway    11106  9295220171
# 7425                 broadway    11106  9295220171
# 7426            dry harbor rd    11379  7183261579
# 7427            s conduit ave    11422  7187122273
# 7428            s conduit ave    11422  7187122273
# 7429                  9th ave    10018  2122791010
# 7430             kingston ave    11213  7187747665
# 7431             kingston ave    11213  7187747665
# 7432  frederick douglass blvd    10026  2126786200
# 7433             sutphin blvd    11435  7182629293
#
#                                     cuisine_description inspection_date  \
# 0                                                Bakery      2017-05-18
# 1                                                Bakery      2018-05-11
# 2                                                Bakery      2019-05-16
# 3                                          Delicatessen      2016-09-13
# 4                                          Delicatessen      2017-12-01
# 5                                          Delicatessen      2018-01-24
# 6                                          Delicatessen      2018-06-05
# 7                                          Delicatessen      2019-05-16
# 8                        Sandwiches/Salads/Mixed Buffet      2016-09-06
# 9                        Sandwiches/Salads/Mixed Buffet      2016-10-07
# 10                       Sandwiches/Salads/Mixed Buffet      2017-03-24
# 11                       Sandwiches/Salads/Mixed Buffet      2018-04-13
# 12                       Sandwiches/Salads/Mixed Buffet      2018-05-25
# 13                       Sandwiches/Salads/Mixed Buffet      2018-10-17
# 14                       Sandwiches/Salads/Mixed Buffet      2018-10-24
# 15                       Sandwiches/Salads/Mixed Buffet      2018-10-30
# 16                       Sandwiches/Salads/Mixed Buffet      2019-01-04
# 17                       Sandwiches/Salads/Mixed Buffet      2019-05-02
# 18                                        Jewish/Kosher      2016-10-20
# 19                                        Jewish/Kosher      2017-12-13
# 20                                        Jewish/Kosher      2018-11-28
# 21                                              Chinese      2017-04-04
# 22                                              Chinese      2018-05-02
# 23                                              Chinese      2019-05-13
# 24                                                Steak      2016-03-22
# 25                                                Steak      2017-06-08
# 26                                                Steak      2017-07-05
# 27                                                Steak      2018-01-18
# 28                                                Steak      2019-02-13
# 29                                                Pizza      2016-09-23
# ...                                                 ...             ...
# 7404                                           Japanese      2019-02-06
# 7405                                           Japanese      2019-03-06
# 7406  Latin (Cuban, Dominican, Puerto Rican, South &...      2019-03-20
# 7407  Latin (Cuban, Dominican, Puerto Rican, South &...      2019-04-16
# 7408                                            Chicken      2019-02-05
# 7409                                            Chicken      2019-03-01
# 7410  Latin (Cuban, Dominican, Puerto Rican, South &...      2019-02-13
# 7411                                            Chicken      2019-02-21
# 7412                                            Chicken      2019-03-15
# 7413                                            Italian      2019-02-14
# 7414                                            Italian      2019-02-26
# 7415                                            Chinese      2019-02-13
# 7416                                            Chinese      2019-04-11
# 7417                                            Chinese      2019-04-23
# 7418                                              Pizza      2019-04-16
# 7419                                              Pizza      2019-05-08
# 7420                                               Thai      2019-04-16
# 7421                                               Thai      2019-05-06
# 7422                                              Pizza      2019-04-09
# 7423                                           American      2019-03-19
# 7424                                             Korean      2019-03-21
# 7425                                             Korean      2019-04-30
# 7426                                             Bakery      2019-05-10
# 7427                                          Caribbean      2019-03-18
# 7428                                          Caribbean      2019-04-29
# 7429                                           Japanese      2019-05-15
# 7430                                              Pizza      2019-05-15
# 7431                                              Pizza      2019-05-17
# 7432                                              Other      2019-05-18
# 7433                                          Caribbean      2019-05-13
#
#                                                  action violation_code  \
# 0       Violations were cited in the following area(s).            06D
# 1       Violations were cited in the following area(s).            08C
# 2       Violations were cited in the following area(s).            04L
# 3       Violations were cited in the following area(s).            06D
# 4       Violations were cited in the following area(s).            02B
# 5       Violations were cited in the following area(s).            04L
# 6       Violations were cited in the following area(s).            06C
# 7       Violations were cited in the following area(s).            04L
# 8       Violations were cited in the following area(s).            02G
# 9       Violations were cited in the following area(s).            04M
# 10      Violations were cited in the following area(s).            06E
# 11      Violations were cited in the following area(s).            02B
# 12      Violations were cited in the following area(s).            06E
# 13    Establishment Closed by DOHMH.  Violations wer...            04H
# 14                     Establishment re-closed by DOHMH            04M
# 15                     Establishment re-opened by DOHMH            10B
# 16      Violations were cited in the following area(s).            06C
# 17      Violations were cited in the following area(s).            02B
# 18      Violations were cited in the following area(s).            02G
# 19      Violations were cited in the following area(s).            04L
# 20      Violations were cited in the following area(s).            04N
# 21      Violations were cited in the following area(s).            10F
# 22      Violations were cited in the following area(s).            04A
# 23      Violations were cited in the following area(s).            02B
# 24      Violations were cited in the following area(s).            02B
# 25      Violations were cited in the following area(s).            02B
# 26      Violations were cited in the following area(s).            06D
# 27      Violations were cited in the following area(s).            04H
# 28      Violations were cited in the following area(s).            06D
# 29      Violations were cited in the following area(s).            02B
# ...                                                 ...            ...
# 7404    Violations were cited in the following area(s).            03A
# 7405    Violations were cited in the following area(s).            06C
# 7406    Violations were cited in the following area(s).            02B
# 7407    Violations were cited in the following area(s).            02G
# 7408    Violations were cited in the following area(s).            04K
# 7409    Violations were cited in the following area(s).            04K
# 7410    Violations were cited in the following area(s).            05D
# 7411    Violations were cited in the following area(s).            04A
# 7412    Violations were cited in the following area(s).            02G
# 7413    Violations were cited in the following area(s).            04C
# 7414    Violations were cited in the following area(s).            06D
# 7415    Violations were cited in the following area(s).            04L
# 7416    Violations were cited in the following area(s).            02B
# 7417    Violations were cited in the following area(s).            04L
# 7418    Violations were cited in the following area(s).            02B
# 7419    Violations were cited in the following area(s).            02B
# 7420    Violations were cited in the following area(s).            02G
# 7421    Violations were cited in the following area(s).            04L
# 7422    Violations were cited in the following area(s).            10F
# 7423    Violations were cited in the following area(s).            10F
# 7424    Violations were cited in the following area(s).            02G
# 7425    Violations were cited in the following area(s).            06C
# 7426    Violations were cited in the following area(s).            04L
# 7427    Violations were cited in the following area(s).            02G
# 7428    Violations were cited in the following area(s).            04L
# 7429    Violations were cited in the following area(s).            02B
# 7430  Establishment Closed by DOHMH.  Violations wer...            02B
# 7431                   Establishment re-opened by DOHMH            04L
# 7432  No violations were recorded at the time of thi...             na
# 7433    Violations were cited in the following area(s).            02B
#
#                                   violation_description   critical_flag  \
# 0     Food contact surface not properly washed, rins...        Critical
# 1     Pesticide use not in accordance with label or ...    Not Critical
# 2     Evidence of mice or live mice present in facil...        Critical
# 3     Food contact surface not properly washed, rins...        Critical
# 4           Hot food item not held at or above 140Âº F.        Critical
# 5     Evidence of mice or live mice present in facil...        Critical
# 6     Food not protected from potential source of co...        Critical
# 7     Evidence of mice or live mice present in facil...        Critical
# 8     Cold food item held above 41Âº F (smoked fish ...        Critical
# 9     Live roaches present in facility's food and/or...        Critical
# 10    Sanitized equipment or utensil, including in-u...        Critical
# 11          Hot food item not held at or above 140Âº F.        Critical
# 12    Sanitized equipment or utensil, including in-u...        Critical
# 13    Raw, cooked or prepared food is adulterated, c...        Critical
# 14    Live roaches present in facility's food and/or...        Critical
# 15    Plumbing not properly installed or maintained;...    Not Critical
# 16    Food not protected from potential source of co...        Critical
# 17          Hot food item not held at or above 140Âº F.        Critical
# 18    Cold food item held above 41Âº F (smoked fish ...        Critical
# 19    Evidence of mice or live mice present in facil...        Critical
# 20    Filth flies or food/refuse/sewage-associated (...        Critical
# 21    Non-food contact surface improperly constructe...    Not Critical
# 22    Food Protection Certificate not held by superv...        Critical
# 23          Hot food item not held at or above 140Âº F.        Critical
# 24          Hot food item not held at or above 140Âº F.        Critical
# 25          Hot food item not held at or above 140Âº F.        Critical
# 26    Food contact surface not properly washed, rins...        Critical
# 27    Raw, cooked or prepared food is adulterated, c...        Critical
# 28    Food contact surface not properly washed, rins...        Critical
# 29          Hot food item not held at or above 140Âº F.        Critical
# ...                                                 ...             ...
# 7404  Food from unapproved or unknown source or home...        Critical
# 7405  Food not protected from potential source of co...        Critical
# 7406        Hot food item not held at or above 140Âº F.        Critical
# 7407  Cold food item held above 41Âº F (smoked fish ...        Critical
# 7408  Evidence of rats or live rats present in facil...        Critical
# 7409  Evidence of rats or live rats present in facil...        Critical
# 7410  Hand washing facility not provided in or near ...        Critical
# 7411  Food Protection Certificate not held by superv...        Critical
# 7412  Cold food item held above 41Âº F (smoked fish ...        Critical
# 7413  Food worker does not use proper utensil to eli...        Critical
# 7414  Food contact surface not properly washed, rins...        Critical
# 7415  Evidence of mice or live mice present in facil...        Critical
# 7416        Hot food item not held at or above 140Âº F.        Critical
# 7417  Evidence of mice or live mice present in facil...        Critical
# 7418        Hot food item not held at or above 140Âº F.        Critical
# 7419        Hot food item not held at or above 140Âº F.        Critical
# 7420  Cold food item held above 41Âº F (smoked fish ...        Critical
# 7421  Evidence of mice or live mice present in facil...        Critical
# 7422  Non-food contact surface improperly constructe...    Not Critical
# 7423  Non-food contact surface improperly constructe...    Not Critical
# 7424  Cold food item held above 41Âº F (smoked fish ...        Critical
# 7425  Food not protected from potential source of co...        Critical
# 7426  Evidence of mice or live mice present in facil...        Critical
# 7427  Cold food item held above 41Âº F (smoked fish ...        Critical
# 7428  Evidence of mice or live mice present in facil...        Critical
# 7429        Hot food item not held at or above 140Âº F.        Critical
# 7430        Hot food item not held at or above 140Âº F.        Critical
# 7431  Evidence of mice or live mice present in facil...        Critical
# 7432                                                 na  Not Applicable
# 7433        Hot food item not held at or above 140Âº F.        Critical
#
#       score                                   inspection_type  \
# 0       7.0             Cycle Inspection / Initial Inspection
# 1       5.0             Cycle Inspection / Initial Inspection
# 2      18.0             Cycle Inspection / Initial Inspection
# 3       8.0             Cycle Inspection / Initial Inspection
# 4      24.0             Cycle Inspection / Initial Inspection
# 5      13.0                  Cycle Inspection / Re-inspection
# 6      11.0             Cycle Inspection / Initial Inspection
# 7      12.0             Cycle Inspection / Initial Inspection
# 8      33.0             Cycle Inspection / Initial Inspection
# 9      24.0                  Cycle Inspection / Re-inspection
# 10     10.0             Cycle Inspection / Initial Inspection
# 11     27.0             Cycle Inspection / Initial Inspection
# 12      5.0                  Cycle Inspection / Re-inspection
# 13     46.0             Cycle Inspection / Initial Inspection
# 14     11.0           Cycle Inspection / Reopening Inspection
# 15      4.0           Cycle Inspection / Reopening Inspection
# 16     12.0                  Cycle Inspection / Re-inspection
# 17     33.0             Cycle Inspection / Initial Inspection
# 18      9.0             Cycle Inspection / Initial Inspection
# 19     11.0             Cycle Inspection / Initial Inspection
# 20     10.0             Cycle Inspection / Initial Inspection
# 21      5.0             Cycle Inspection / Initial Inspection
# 22     12.0             Cycle Inspection / Initial Inspection
# 23     21.0             Cycle Inspection / Initial Inspection
# 24     10.0             Cycle Inspection / Initial Inspection
# 25     27.0             Cycle Inspection / Initial Inspection
# 26      5.0                  Cycle Inspection / Re-inspection
# 27     13.0             Cycle Inspection / Initial Inspection
# 28      5.0             Cycle Inspection / Initial Inspection
# 29     11.0             Cycle Inspection / Initial Inspection
# ...     ...                                               ...
# 7404   12.0     Pre-permit (Operational) / Initial Inspection
# 7405    8.0          Pre-permit (Operational) / Re-inspection
# 7406   36.0     Pre-permit (Operational) / Initial Inspection
# 7407   22.0          Pre-permit (Operational) / Re-inspection
# 7408   19.0     Pre-permit (Operational) / Initial Inspection
# 7409   12.0          Pre-permit (Operational) / Re-inspection
# 7410   12.0     Pre-permit (Operational) / Initial Inspection
# 7411   21.0     Pre-permit (Operational) / Initial Inspection
# 7412   12.0          Pre-permit (Operational) / Re-inspection
# 7413   22.0     Pre-permit (Operational) / Initial Inspection
# 7414    7.0          Pre-permit (Operational) / Re-inspection
# 7415   19.0     Pre-permit (Operational) / Initial Inspection
# 7416   41.0          Pre-permit (Operational) / Re-inspection
# 7417   21.0  Pre-permit (Operational) / Compliance Inspection
# 7418   18.0     Pre-permit (Operational) / Initial Inspection
# 7419    9.0          Pre-permit (Operational) / Re-inspection
# 7420   43.0     Pre-permit (Operational) / Initial Inspection
# 7421   10.0          Pre-permit (Operational) / Re-inspection
# 7422    2.0     Pre-permit (Operational) / Initial Inspection
# 7423    2.0     Pre-permit (Operational) / Initial Inspection
# 7424   21.0     Pre-permit (Operational) / Initial Inspection
# 7425   12.0          Pre-permit (Operational) / Re-inspection
# 7426   40.0     Pre-permit (Operational) / Initial Inspection
# 7427   33.0     Pre-permit (Operational) / Initial Inspection
# 7428   13.0          Pre-permit (Operational) / Re-inspection
# 7429   33.0     Pre-permit (Operational) / Initial Inspection
# 7430   68.0     Pre-permit (Operational) / Initial Inspection
# 7431    9.0   Pre-permit (Operational) / Reopening Inspection
# 7432    0.0      Inter-Agency Task Force / Initial Inspection
# 7433   28.0     Pre-permit (Operational) / Initial Inspection
#
#                            address  zip_code  rating price       cuisine
# 0             1007 morris park ave     10462     4.0    $$      bakeries
# 1             1007 morris park ave     10462     4.0    $$      bakeries
# 2             1007 morris park ave     10462     4.0    $$      bakeries
# 3                     12908 20 ave     11356     4.5     $         delis
# 4                     12908 20 ave     11356     4.5     $         delis
# 5                     12908 20 ave     11356     4.5     $         delis
# 6                     12908 20 ave     11356     4.5     $         delis
# 7                     12908 20 ave     11356     4.5     $         delis
# 8                       60 wall st     10005     2.0     $    sandwiches
# 9                       60 wall st     10005     2.0     $    sandwiches
# 10                      60 wall st     10005     2.0     $    sandwiches
# 11                      60 wall st     10005     2.0     $    sandwiches
# 12                      60 wall st     10005     2.0     $    sandwiches
# 13                      60 wall st     10005     2.0     $    sandwiches
# 14                      60 wall st     10005     2.0     $    sandwiches
# 15                      60 wall st     10005     2.0     $    sandwiches
# 16                      60 wall st     10005     2.0     $    sandwiches
# 17                      60 wall st     10005     2.0     $    sandwiches
# 18                      1423 ave j     11230     4.0     $        bagels
# 19                      1423 ave j     11230     4.0     $        bagels
# 20                      1423 ave j     11230     4.0     $        bagels
# 21            277 e kingsbridge rd     10458     4.0     $       chinese
# 22            277 e kingsbridge rd     10458     4.0     $       chinese
# 23            277 e kingsbridge rd     10458     4.0     $       chinese
# 24               845 lexington ave     10065     3.5    $$         steak
# 25               845 lexington ave     10065     3.5    $$         steak
# 26               845 lexington ave     10065     3.5    $$         steak
# 27               845 lexington ave     10065     3.5    $$         steak
# 28               845 lexington ave     10065     3.5    $$         steak
# 29                3013 steinway st     11103     4.0     $         pizza
# ...                            ...       ...     ...   ...           ...
# 7404             964 amsterdam ave     10025     3.0    $$         sushi
# 7405             964 amsterdam ave     10025     3.0    $$         sushi
# 7406                   9107 31 ave     11369     2.5     $         latin
# 7407                   9107 31 ave     11369     2.5     $         latin
# 7408               122 wyckoff ave     11237     4.5     $      peruvian
# 7409               122 wyckoff ave     11237     4.5     $      peruvian
# 7410                  9712 101 ave     11416     3.0    $$       spanish
# 7411           13105 rockaway blvd     11420     2.0     $   chickenshop
# 7412           13105 rockaway blvd     11420     2.0     $   chickenshop
# 7413             886 amsterdam ave     10025     4.0    $$       italian
# 7414             886 amsterdam ave     10025     4.0    $$       italian
# 7415           5952 summerfield st     11385     4.5     $       chinese
# 7416           5952 summerfield st     11385     4.5     $       chinese
# 7417           5952 summerfield st     11385     4.5     $       chinese
# 7418                  188 e 104 st     10029     4.0     $         pizza
# 7419                  188 e 104 st     10029     4.0     $         pizza
# 7420              17819 union tpke     11366     4.5    $$          thai
# 7421              17819 union tpke     11366     4.5    $$          thai
# 7422             4369 kissena blvd     11355     3.0     $         pizza
# 7423             148 bruckner blvd     10454     4.0    $$       burgers
# 7424                   2530 brdway     11106     4.0    $$        korean
# 7425                   2530 brdway     11106     4.0    $$        korean
# 7426            6459 dry harbor rd     11379     3.5    $$      bakeries
# 7427           24712 s conduit ave     11422     2.5     $     caribbean
# 7428           24712 s conduit ave     11422     2.5     $     caribbean
# 7429                     462 9 ave     10018     3.5    $$         sushi
# 7430              259 kingston ave     11213     2.5     $         pizza
# 7431              259 kingston ave     11213     2.5     $         pizza
# 7432  2149 frederick douglass blvd     10026     4.0    $$  tradamerican
# 7433             9058 sutphin blvd     11435     2.0    $$      bakeries
#
# [7434 rows x 20 columns]

# %%
len(df_combined.camis.unique())
# Out:
# 1325

# %% [markdown]
# ### Save the data as csv

# %%
df_combined.to_csv('../final.csv')
